# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/content'

# %%
# Reading the dataset
df = pd.read_csv('/content/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Finding the shape (rows,columns)
df.shape
# Out:
# (1338, 7)

# %%
# Find the dtype of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Checking the null values
df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
# Checking the null values
df.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
# Checking the null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['age'].mean(),df['age'].median(),df['age'].mode()[0]
# Out:
# (39.20702541106129, 39.0, 18)

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
# df['age'] = df['age'].fillna(df['age'].mean())

# %%
# Mean, median & Mode

# %%
# Finding unique values

df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
# Rows & columns ----> observation & features

# %%
# EDA

# %%
# Scatterplot (seaborn)

sns.scatterplot(x='bmi',y='charges',data=df)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
plt.scatter(x='bmi',y='charges',data=df)

# %%
# sns.countplot(df['region'])

# %%
sns.countplot(x='region',data=df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
# Encoding --- 3 types ---
"""
1. One hot encoding
2. Label encoding
3. manual encoding
"""
# Out:
# '\n1. One hot encoding\n2. Label encoding\n3. manual encoding\n'

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# One Hot encoding
df_onehot = pd.get_dummies(df,columns=['sex'])
df_onehot
# Out:
#       age     bmi  children smoker     region      charges  sex_female  \
# 0      19  27.900         0    yes  southwest  16884.92400           1
# 1      18  33.770         1     no  southeast   1725.55230           0
# 2      28  33.000         3     no  southeast   4449.46200           0
# 3      33  22.705         0     no  northwest  21984.47061           0
# 4      32  28.880         0     no  northwest   3866.85520           0
# ...   ...     ...       ...    ...        ...          ...         ...
# 1333   50  30.970         3     no  northwest  10600.54830           0
# 1334   18  31.920         0     no  northeast   2205.98080           1
# 1335   18  36.850         0     no  southeast   1629.83350           1
# 1336   21  25.800         0     no  southwest   2007.94500           1
# 1337   61  29.070         0    yes  northwest  29141.36030           1
#
#       sex_male
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# ...

# %%
# One Hot encoding
df_onehot1 = pd.get_dummies(df,columns=['region'])
df_onehot1
# Out:
#       age     sex     bmi  children smoker      charges  region_northeast  \
# 0      19  female  27.900         0    yes  16884.92400                 0
# 1      18    male  33.770         1     no   1725.55230                 0
# 2      28    male  33.000         3     no   4449.46200                 0
# 3      33    male  22.705         0     no  21984.47061                 0
# 4      32    male  28.880         0     no   3866.85520                 0
# ...   ...     ...     ...       ...    ...          ...               ...
# 1333   50    male  30.970         3     no  10600.54830                 0
# 1334   18  female  31.920         0     no   2205.98080                 1
# 1335   18  female  36.850         0     no   1629.83350                 0
# 1336   21  female  25.800         0     no   2007.94500                 0
# 1337   61  female  29.070         0    yes  29141.36030                 0
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
# Label encoder

from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['regionLabelEncoder'] = le.fit_transform(df['region'])

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#       regionLabelEncoder
# 0                      3
# 1                      2
# 2                      2
# 3                      1
# 4                      1
# ...

# %%
# Manual encoding

df['smokerManualEncoding'] = df['smoker'].replace({'yes':1,'no':0})

# %%
df['sex'] = df['sex'].replace({'female':1,'male':0})

# %%
df
# Out:
#       age  sex     bmi  children smoker     region      charges  \
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    0  30.970         3     no  northwest  10600.54830
# 1334   18    1  31.920         0     no  northeast   2205.98080
# 1335   18    1  36.850         0     no  southeast   1629.83350
# 1336   21    1  25.800         0     no  southwest   2007.94500
# 1337   61    1  29.070         0    yes  northwest  29141.36030
#
#       regionLabelEncoder  smokerManualEncoding
# 0                      3                     1
# 1                      2                     0
# 2                      2                     0
# ...

# %%
df['children'].unique(), df['charges'].unique()
# Out:
# (array([0, 1, 3, 2, 5, 4]),
#  array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#         29141.3603]))

# %%
# Removing the columns

df.drop(['smoker','region'],axis=1,inplace=True)

# df = df.drop(['smoker','region'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   1338 non-null   int64
#  1   sex                   1338 non-null   int64
#  2   bmi                   1338 non-null   float64
#  3   children              1338 non-null   int64
#  4   charges               1338 non-null   float64
#  5   regionLabelEncoder    1338 non-null   int64
#  6   smokerManualEncoding  1338 non-null   int64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
# Scaling --> Normalization, Standardisation

from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
ss = StandardScaler()
ss.fit_transform(df)
# Out:
# array([[-1.43876426,  1.0105187 , -0.45332   , ...,  0.2985838 ,
#          1.34390459,  1.97058663],
#        [-1.50996545, -0.98959079,  0.5096211 , ..., -0.95368917,
#          0.43849455, -0.5074631 ],
#        [-0.79795355, -0.98959079,  0.38330685, ..., -0.72867467,
#          0.43849455, -0.5074631 ],
#        ...,
#        [-1.50996545,  1.0105187 ,  1.0148781 , ..., -0.96159623,
#          0.43849455, -0.5074631 ],
#        [-1.29636188,  1.0105187 , -0.79781341, ..., -0.93036151,
#          1.34390459, -0.5074631 ],
#        [ 1.55168573,  1.0105187 , -0.26138796, ...,  1.31105347,
#         -0.46691549,  1.97058663]])

# %%
df.head()
# Out:
#    age  sex     bmi  children      charges  regionLabelEncoder  \
# 0   19    1  27.900         0  16884.92400                   3
# 1   18    0  33.770         1   1725.55230                   2
# 2   28    0  33.000         3   4449.46200                   2
# 3   33    0  22.705         0  21984.47061                   1
# 4   32    0  28.880         0   3866.85520                   1
#
#    smokerManualEncoding
# 0                     1
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
mm = MinMaxScaler()
mm.fit_transform(df)
# Out:
# array([[0.02173913, 1.        , 0.3212268 , ..., 0.25161076, 1.        ,
#         1.        ],
#        [0.        , 0.        , 0.47914985, ..., 0.00963595, 0.66666667,
#         0.        ],
#        [0.2173913 , 0.        , 0.45843422, ..., 0.05311516, 0.66666667,
#         0.        ],
#        ...,
#        [0.        , 1.        , 0.56201238, ..., 0.00810808, 0.66666667,
#         0.        ],
#        [0.06521739, 1.        , 0.26472962, ..., 0.01414352, 1.        ,
#         0.        ],
#        [0.93478261, 1.        , 0.35270379, ..., 0.44724873, 0.33333333,
#         1.        ]])

# %% [markdown]
# ## Machine learning ---
#
# 1) Supervised learning (Combination of independent[x] and dependent[y] variables) -- (Regression & Classification)
# 2) Unsupervised learning (independent variables)-- (Clustering)

# %%
# Splitting the data

x = df.drop(['charges'],axis=1)  # Independent variables
x
# Out:
#       age  sex     bmi  children  regionLabelEncoder  smokerManualEncoding
# 0      19    1  27.900         0                   3                     1
# 1      18    0  33.770         1                   2                     0
# 2      28    0  33.000         3                   2                     0
# 3      33    0  22.705         0                   1                     0
# 4      32    0  28.880         0                   1                     0
# ...   ...  ...     ...       ...                 ...                   ...
# 1333   50    0  30.970         3                   1                     0
# 1334   18    1  31.920         0                   0                     0
# 1335   18    1  36.850         0                   2                     0
# 1336   21    1  25.800         0                   3                     0
# 1337   61    1  29.070         0                   1                     1
#
# [1338 rows x 6 columns]

# %%
df['charges'].values
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
y = df['charges'] # Dependent variable
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
# Simple LR ---> y = mx+c ---> eg: y = 0.4 x X + 2.4
# Multi LR ---> y = mx1+mx2+mxn+c ---> eg: y = (0.4 x X1) + (0.4 x X2) + (0.4 x X3) + 2.4
